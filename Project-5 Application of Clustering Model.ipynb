# %% [markdown]
# # Project on Clustering
# Problem Statement
#
# Problem 1: There are various stocks for which we have collected a data set, which all stocks are apparently similar in performance
#
# Problem 2: How many Unique patterns that exist in the historical stock data set, based on fluctuations in price.
#
# Problem 3: Identify which all stocks are moving together and which all stocks are different from each other.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('data_stocks.csv')

# %%
data.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN    ...     NYSE.WYN  \
# 0    102.2300      85.2200       59.760       121.52    ...       84.370
# 1    102.1400      85.6500       59.840       121.48    ...       84.370
# 2    102.2125      85.5100       59.795       121.93    ...       84.585
# 3    102.1400      85.4872       59.620       121.44    ...       84.460
# 4    102.0600      85.7001       59.620       121.60    ...       84.470
#
#    NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  \
# 0   119.035     44.40    39.88     82.03      7.36     50.22     63.86
# 1   119.035     44.11    39.88     82.03      7.38     50.22     63.74
# 2   119.260     44.09    39.98     82.02      7.36     50.12     63.75
# 3   119.260     44.25    39.99     82.02      7.35     50.16     63.88
# 4   119.610     44.11    39.96     82.03      7.36     50.20     63.91
#
#    NYSE.ZBH  NYSE.ZTS
# 0   122.000    53.350
# 1   121.770    53.350
# 2   121.700    53.365
# 3   121.700    53.380
# 4   121.695    53.240
#
# [5 rows x 502 columns]

# %%
data.shape
# Out:
# (41266, 502)

# %%
data.columns
# Out:
# Index(['DATE', 'SP500', 'NASDAQ.AAL', 'NASDAQ.AAPL', 'NASDAQ.ADBE',
#        'NASDAQ.ADI', 'NASDAQ.ADP', 'NASDAQ.ADSK', 'NASDAQ.AKAM', 'NASDAQ.ALXN',
#        ...
#        'NYSE.WYN', 'NYSE.XEC', 'NYSE.XEL', 'NYSE.XL', 'NYSE.XOM', 'NYSE.XRX',
#        'NYSE.XYL', 'NYSE.YUM', 'NYSE.ZBH', 'NYSE.ZTS'],
#       dtype='object', length=502)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41266 entries, 0 to 41265
# Columns: 502 entries, DATE to NYSE.ZTS
# dtypes: float64(501), int64(1)
# memory usage: 158.0 MB

# %%
data_cor = data.copy()
data_cor.drop(['DATE'],inplace = True, axis=1)

# %% [markdown]
# #### Problem 1: There are various stocks for which we have collected a data set, which all stocks are apparently similar in performance

# %%
# Finding correlation between variables - identify highly correlated variables
cor = data_cor.corr()

# %%
cor_dt = pd.DataFrame(data=cor.values, columns=cor.index, index = cor.index)
cor_dt.head()
# Out:
#                 SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# SP500        1.000000    0.712007     0.553332     0.909061    0.219471
# NASDAQ.AAL   0.712007    1.000000     0.082065     0.542213    0.209446
# NASDAQ.AAPL  0.553332    0.082065     1.000000     0.714578    0.264269
# NASDAQ.ADBE  0.909061    0.542213     0.714578     1.000000    0.259282
# NASDAQ.ADI   0.219471    0.209446     0.264269     0.259282    1.000000
#
#              NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  \
# SP500          0.562785     0.834350    -0.690018     0.450572     0.752814
# NASDAQ.AAL     0.245801     0.610881    -0.441142     0.009581     0.681863
# NASDAQ.AAPL    0.265641     0.645233    -0.712522     0.326712     0.545541
# NASDAQ.ADBE    0.476496     0.872353    -0.759604     0.488717     0.733609
# NASDAQ.ADI    -0.085074     0.470756    -0.323603    -0.409747     0.504019
#
#                ...     NYSE.WYN  NYSE.XEC  NYSE.XEL   NYSE.XL  NYSE.XOM  \
# SP500          ...     0.847975 -0.848511  0.741641  0.820043 -0.517492
# NASDAQ.AAL     ...     0.798624 -0.744085  0.284370  0.810955 -0.070950
# NASDAQ.AAPL    ...     0.306664 -0.250959  0.738655  0.266994 -0.671488
# NASDAQ.ADBE    ...     0.718851 -0.792876  0.850709  0.722161 -0.758967
# NASDAQ.ADI     ...     0.203224 -0.160317  0.308948  0.050697 -0.024428
#
#              NYSE.XRX  NYSE.XYL  NYSE.YUM  NYSE.ZBH  NYSE.ZTS
# SP500        0.805525  0.849908  0.915986  0.143752  0.813459
# NASDAQ.AAL   0.522341  0.395730  0.642336  0.588241  0.753567
# NASDAQ.AAPL  0.341687  0.693062  0.627531 -0.580055  0.442600
# NASDAQ.ADBE  0.806615  0.911106  0.939185 -0.067235  0.776052
# NASDAQ.ADI  -0.017967  0.067258  0.261173  0.130786  0.351893
#
# [5 rows x 501 columns]

# %%
cor_dt[cor_dt['SP500'].values > 0.80][:5]
# Out:
#                 SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# SP500        1.000000    0.712007     0.553332     0.909061    0.219471
# NASDAQ.ADBE  0.909061    0.542213     0.714578     1.000000    0.259282
# NASDAQ.ADSK  0.834350    0.610881     0.645233     0.872353    0.470756
# NASDAQ.AMZN  0.834878    0.803319     0.370111     0.730719    0.386619
# NASDAQ.ATVI  0.922833    0.593574     0.704358     0.961857    0.321411
#
#              NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  \
# SP500          0.562785     0.834350    -0.690018     0.450572     0.752814
# NASDAQ.ADBE    0.476496     0.872353    -0.759604     0.488717     0.733609
# NASDAQ.ADSK    0.325630     1.000000    -0.845720     0.102522     0.871658
# NASDAQ.AMZN    0.252712     0.828757    -0.648854     0.059345     0.897693
# NASDAQ.ATVI    0.421174     0.923135    -0.850687     0.375481     0.802540
#
#                ...     NYSE.WYN  NYSE.XEC  NYSE.XEL   NYSE.XL  NYSE.XOM  \
# SP500          ...     0.847975 -0.848511  0.741641  0.820043 -0.517492
# NASDAQ.ADBE    ...     0.718851 -0.792876  0.850709  0.722161 -0.758967
# NASDAQ.ADSK    ...     0.789021 -0.717767  0.824764  0.671072 -0.531723
# NASDAQ.AMZN    ...     0.879967 -0.733852  0.530139  0.804398 -0.203979
# NASDAQ.ATVI    ...     0.797973 -0.815299  0.874434  0.723013 -0.652308
#
#              NYSE.XRX  NYSE.XYL  NYSE.YUM  NYSE.ZBH  NYSE.ZTS
# SP500        0.805525  0.849908  0.915986  0.143752  0.813459
# NASDAQ.ADBE  0.806615  0.911106  0.939185 -0.067235  0.776052
# NASDAQ.ADSK  0.577194  0.701701  0.915175  0.016689  0.884658
# NASDAQ.AMZN  0.533584  0.503878  0.793529  0.419472  0.872246
# NASDAQ.ATVI  0.763749  0.857080  0.972927 -0.025171  0.875018
#
# [5 rows x 501 columns]

# %%
cor_dt[cor_dt['NASDAQ.AAL'].values > 0.80][:5]
# Out:
#                 SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# NASDAQ.AAL   0.712007    1.000000     0.082065     0.542213    0.209446
# NASDAQ.AMZN  0.834878    0.803319     0.370111     0.730719    0.386619
# NASDAQ.EXPE  0.892177    0.812206     0.379622     0.818384    0.218189
# NASDAQ.HAS   0.473669    0.832713    -0.274890     0.251696    0.252954
# NYSE.CMI     0.720325    0.810391     0.088336     0.528227    0.206259
#
#              NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  \
# NASDAQ.AAL     0.245801     0.610881    -0.441142     0.009581     0.681863
# NASDAQ.AMZN    0.252712     0.828757    -0.648854     0.059345     0.897693
# NASDAQ.EXPE    0.369697     0.834440    -0.707045     0.296553     0.817588
# NASDAQ.HAS    -0.030201     0.394658    -0.206013    -0.208923     0.530874
# NYSE.CMI       0.179664     0.577301    -0.458993     0.140823     0.690999
#
#                ...     NYSE.WYN  NYSE.XEC  NYSE.XEL   NYSE.XL  NYSE.XOM  \
# NASDAQ.AAL     ...     0.798624 -0.744085  0.284370  0.810955 -0.070950
# NASDAQ.AMZN    ...     0.879967 -0.733852  0.530139  0.804398 -0.203979
# NASDAQ.EXPE    ...     0.931258 -0.825230  0.591514  0.859042 -0.368192
# NASDAQ.HAS     ...     0.698866 -0.609800  0.035341  0.625126  0.264187
# NYSE.CMI       ...     0.803020 -0.677137  0.226787  0.767652 -0.003402
#
#              NYSE.XRX  NYSE.XYL  NYSE.YUM  NYSE.ZBH  NYSE.ZTS
# NASDAQ.AAL   0.522341  0.395730  0.642336  0.588241  0.753567
# NASDAQ.AMZN  0.533584  0.503878  0.793529  0.419472  0.872246
# NASDAQ.EXPE  0.712184  0.658203  0.883902  0.347660  0.913009
# NASDAQ.HAS   0.306630  0.055201  0.406760  0.839854  0.651842
# NYSE.CMI     0.521924  0.370814  0.616157  0.581472  0.753369
#
# [5 rows x 501 columns]

# %% [markdown]
# #### Problem 2: How many Unique patterns that exist in the historical stock data set, based on fluctuations in price.¶

# %%
from numpy import vstack,array
from numpy.random import rand
import numpy as np
from scipy.cluster.vq import kmeans,vq
import pandas as pd
from math import sqrt
from sklearn.cluster import KMeans

# %%
returns = data.pct_change().mean()*252
returns = pd.DataFrame(returns)
returns.columns = ['Returns']
returns.Volatility = data.pct_change().std()*sqrt(252)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   after removing the cwd from sys.path.

# %%
# format the data into numpy array to feed into K-means algorithm
dta = np.asarray([np.asarray(returns.Returns), np.asarray(returns.Volatility)]).T

# %%
X = dta
distortions =[]
for k in range(2,20):
    k_means = KMeans(n_clusters = k)
    k_means.fit(X)
    distortions.append(k_means.inertia_)

fig = plt.figure(figsize=(15,5))
plt.plot(range(2,20),distortions)
plt.grid(True)
plt.title('Elbow-Curve')
plt.show()

# %%
from pylab import plot, show
# Computing kmeans with K = 5 (5 clusters)
centroids,_= kmeans(dta, 5)
# Assign each sample to a cluster
idx,_ = vq(dta, centroids)

# some plotting using numpy's logical indexing
plot(dta[idx==0,0],dta[idx==0,1],'ob',
     dta[idx==1,0],dta[idx==1,1],'oy',
     dta[idx==2,0],dta[idx==2,1],'or',
     dta[idx==3,0],dta[idx==3,1],'og',
     dta[idx==4,0],dta[idx==4,1],'om')
plot(centroids[:,0],centroids[:,1],'sg',markersize=8)
show()

# %% [markdown]
# It looks like we have an outlier in the data which is skewing the results and making it difficult to actually see what is going on for all the other stocks. Let’s take the easy route and just delete the outlier from our data set and run this again.

# %%
#identify the outlier
print(returns.idxmax())
# Out:
# Returns    NYSE.XRX
# dtype: object

# %%
#drop the relevant stock from our data
data.drop(['NYSE.XRX','DATE','SP500'],inplace=True,axis=1)

# %%
returns = data.pct_change().mean()*252
returns = pd.DataFrame(returns)
returns.columns = ['Returns']
returns.Volatility = data.pct_change().std()*sqrt(252)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   after removing the cwd from sys.path.

# %%
# format the data into numpy array to feed into K-means algorithm
#recreate data to feed into the algorithm
dta = np.asarray([np.asarray(returns.Returns), np.asarray(returns.Volatility)]).T

# %%
# Computing kmeans with K =5 (5 clusters)
centroids,_= kmeans(dta, 5)
# Assign each sample to a cluster
idx,_ = vq(dta, centroids)

# some plotting using numpy's logical indexing
plot(dta[idx==0,0],dta[idx==0,1],'ob',
     dta[idx==1,0],dta[idx==1,1],'oy',
     dta[idx==2,0],dta[idx==2,1],'or',
     dta[idx==3,0],dta[idx==3,1],'og',
     dta[idx==4,0],dta[idx==4,1],'om')
plot(centroids[:,0],centroids[:,1],'sg',markersize=8)
show()

# %%
details = [(name,cluster) for name, cluster in zip(returns.index,idx)]
details[:5]
for detail in details:
    print(list(detail))
# Out:
# ['NASDAQ.AAL', 2]
# ['NASDAQ.AAPL', 4]
# ['NASDAQ.ADBE', 4]
# ['NASDAQ.ADI', 3]
# ['NASDAQ.ADP', 3]
# ['NASDAQ.ADSK', 2]
# ['NASDAQ.AKAM', 2]
# ['NASDAQ.ALXN', 2]
# ['NASDAQ.AMAT', 2]
# ['NASDAQ.AMD', 1]
# ['NASDAQ.AMGN', 4]
# ['NASDAQ.AMZN', 3]
# ['NASDAQ.ATVI', 3]
# ['NASDAQ.AVGO', 3]
# ['NASDAQ.BBBY', 2]
# ['NASDAQ.BIIB', 3]
# ['NASDAQ.CA', 2]
# ['NASDAQ.CBOE', 4]
# ['NASDAQ.CELG', 4]
# ['NASDAQ.CERN', 4]
# ['NASDAQ.CHRW', 3]
# ['NASDAQ.CHTR', 2]
# ['NASDAQ.CINF', 4]
# ['NASDAQ.CMCSA', 4]
# ['NASDAQ.CME', 4]
# ['NASDAQ.COST', 4]
# ['NASDAQ.CSCO', 4]
# ['NASDAQ.CSX', 3]
# ['NASDAQ.CTAS', 4]
# ['NASDAQ.CTSH', 0]
# ['NASDAQ.CTXS', 3]
# ['NASDAQ.DISCA', 2]
# ['NASDAQ.DISCK', 2]
# ['NASDAQ.DISH', 2]
# ['NASDAQ.DLTR', 2]
# ['NASDAQ.EA', 2]
# ['NASDAQ.EBAY', 3]
# ['NASDAQ.EQIX', 3]
# ['NASDAQ.ESRX', 2]
# ['NASDAQ.ETFC', 3]
# ['NASDAQ.EXPD', 4]
# ['NASDAQ.EXPE', 3]
# ['NASDAQ.FAST', 2]
# ['NASDAQ.FB', 4]
# ['NASDAQ.FFIV', 2]
# ['NASDAQ.FISV', 0]
# ['NASDAQ.FITB', 3]
# ['NASDAQ.FLIR', 3]
# ['NASDAQ.FOX', 3]
# ['NASDAQ.FOXA', 3]
# ['NASDAQ.GILD', 4]
# ['NASDAQ.GOOG', 4]
# ['NASDAQ.GOOGL', 4]
# ['NASDAQ.GRMN', 4]
# ['NASDAQ.GT', 2]
# ['NASDAQ.HAS', 3]
# ['NASDAQ.HBAN', 2]
# ['NASDAQ.HOLX', 3]
# ['NASDAQ.HSIC', 3]
# ['NASDAQ.IDXX', 3]
# ['NASDAQ.ILMN', 2]
# ['NASDAQ.INCY', 1]
# ['NASDAQ.INFO', 0]
# ['NASDAQ.INTC', 4]
# ['NASDAQ.INTU', 3]
# ['NASDAQ.ISRG', 4]
# ['NASDAQ.JBHT', 3]
# ['NASDAQ.KHC', 0]
# ['NASDAQ.KLAC', 3]
# ['NASDAQ.LKQ', 3]
# ['NASDAQ.LRCX', 2]
# ['NASDAQ.MAR', 4]
# ['NASDAQ.MAT', 2]
# ['NASDAQ.MCHP', 3]
# ['NASDAQ.MDLZ', 4]
# ['NASDAQ.MNST', 4]
# ['NASDAQ.MSFT', 0]
# ['NASDAQ.MU', 2]
# ['NASDAQ.MYL', 2]
# ['NASDAQ.NAVI', 2]
# ['NASDAQ.NDAQ', 0]
# ['NASDAQ.NFLX', 2]
# ['NASDAQ.NTAP', 3]
# ['NASDAQ.NTRS', 3]
# ['NASDAQ.NVDA', 1]
# ['NASDAQ.NWS', 1]
# ['NASDAQ.NWSA', 3]
# ['NASDAQ.ORLY', 2]
# ['NASDAQ.PAYX', 0]
# ['NASDAQ.PBCT', 3]
# ['NASDAQ.PCAR', 3]
# ['NASDAQ.PCLN', 3]
# ['NASDAQ.PDCO', 2]
# ['NASDAQ.PYPL', 3]
# ['NASDAQ.QCOM', 4]
# ['NASDAQ.QRVO', 2]
# ['NASDAQ.REGN', 2]
# ['NASDAQ.ROST', 2]
# ['NASDAQ.SBUX', 4]
# ['NASDAQ.SNI', 2]
# ['NASDAQ.SNPS', 4]
# ['NASDAQ.SPLS', 2]
# ['NASDAQ.SRCL', 3]
# ['NASDAQ.STX', 1]
# ['NASDAQ.SWKS', 3]
# ['NASDAQ.SYMC', 3]
# ['NASDAQ.TRIP', 1]
# ['NASDAQ.TROW', 4]
# ['NASDAQ.TSCO', 2]
# ['NASDAQ.TXN', 4]
# ['NASDAQ.ULTA', 2]
# ['NASDAQ.VIAB', 2]
# ['NASDAQ.VRSK', 4]
# ['NASDAQ.VRSN', 4]
# ['NASDAQ.VRTX', 1]
# ['NASDAQ.WBA', 4]
# ['NASDAQ.WDC', 2]
# ['NASDAQ.WFM', 1]
# ['NASDAQ.WLTW', 4]
# ['NASDAQ.WYNN', 2]
# ['NASDAQ.XLNX', 3]
# ['NASDAQ.XRAY', 3]
# ['NASDAQ.ZION', 2]
# ['NYSE.A', 4]
# ['NYSE.AAP', 1]
# ['NYSE.ABBV', 0]
# ['NYSE.ABC', 3]
# ['NYSE.ABT', 0]
# ['NYSE.ACN', 0]
# ['NYSE.ADM', 3]
# ['NYSE.ADS', 2]
# ['NYSE.AEE', 0]
# ['NYSE.AEP', 0]
# ['NYSE.AES', 3]
# ['NYSE.AET', 4]
# ['NYSE.AFL', 0]
# ['NYSE.AGN', 4]
# ['NYSE.AIG', 0]
# ['NYSE.AIV', 4]
# ['NYSE.AIZ', 4]
# ['NYSE.AJG', 4]
# ['NYSE.ALB', 3]
# ['NYSE.ALK', 3]
# ['NYSE.ALL', 0]
# ['NYSE.ALLE', 4]
# ['NYSE.AME', 0]
# ['NYSE.AMG', 3]
# ['NYSE.AMP', 3]
# ['NYSE.AMT', 4]
# ['NYSE.AN', 2]
# ['NYSE.ANTM', 3]
# ['NYSE.AON', 0]
# ['NYSE.APA', 2]
# ['NYSE.APC', 2]
# ['NYSE.APD', 0]
# ['NYSE.APH', 0]
# ['NYSE.ARE', 4]
# ['NYSE.ARNC', 2]
# ['NYSE.AVB', 4]
# ['NYSE.AVY', 0]
# ['NYSE.AWK', 0]
# ['NYSE.AXP', 0]
# ['NYSE.AYI', 1]
# ['NYSE.AZO', 2]
# ['NYSE.BA', 4]
# ['NYSE.BAC', 3]
# ['NYSE.BAX', 0]
# ['NYSE.BBT', 4]
# ['NYSE.BBY', 2]
# ['NYSE.BCR', 2]
# ['NYSE.BDX', 4]
# ['NYSE.BEN', 4]
# ['NYSE.BF.B', 3]
# ['NYSE.BHI', 1]
# ['NYSE.BK', 4]
# ['NYSE.BLK', 4]
# ['NYSE.BLL', 1]
# ['NYSE.BMY', 4]
# ['NYSE.BRK.B', 0]
# ['NYSE.BSX', 0]
# ['NYSE.BWA', 2]
# ['NYSE.BXP', 4]
# ['NYSE.C', 3]
# ['NYSE.CAG', 4]
# ['NYSE.CAH', 2]
# ['NYSE.CAT', 3]
# ['NYSE.CB', 0]
# ['NYSE.CBG', 3]
# ['NYSE.CBS', 3]
# ['NYSE.CCI', 4]
# ['NYSE.CCL', 4]
# ['NYSE.CF', 2]
# ['NYSE.CFG', 2]
# ['NYSE.CHD', 0]
# ['NYSE.CHK', 1]
# ['NYSE.CI', 4]
# ['NYSE.CL', 0]
# ['NYSE.CLX', 0]
# ['NYSE.CMA', 3]
# ['NYSE.CMG', 2]
# ['NYSE.CMI', 3]
# ['NYSE.CMS', 0]
# ['NYSE.CNC', 3]
# ['NYSE.CNP', 0]
# ['NYSE.COF', 3]
# ['NYSE.COG', 2]
# ['NYSE.COH', 2]
# ['NYSE.COL', 3]
# ['NYSE.COO', 3]
# ['NYSE.COP', 3]
# ['NYSE.COTY', 2]
# ['NYSE.CPB', 4]
# ['NYSE.CRM', 4]
# ['NYSE.CSRA', 3]
# ['NYSE.CTL', 2]
# ['NYSE.CVS', 4]
# ['NYSE.CVX', 0]
# ['NYSE.CXO', 2]
# ['NYSE.D', 0]
# ['NYSE.DAL', 3]
# ['NYSE.DD', 4]
# ['NYSE.DE', 3]
# ['NYSE.DFS', 4]
# ['NYSE.DG', 2]
# ['NYSE.DGX', 0]
# ['NYSE.DHI', 3]
# ['NYSE.DHR', 0]
# ['NYSE.DIS', 4]
# ['NYSE.DLPH', 3]
# ['NYSE.DLR', 4]
# ['NYSE.DOV', 3]
# ['NYSE.DOW', 4]
# ['NYSE.DPS', 4]
# ['NYSE.DRI', 4]
# ['NYSE.DTE', 0]
# ['NYSE.DUK', 0]
# ['NYSE.DVA', 4]
# ['NYSE.DVN', 2]
# ['NYSE.DXC', 4]
# ['NYSE.ECL', 0]
# ['NYSE.ED', 0]
# ['NYSE.EFX', 4]
# ['NYSE.EIX', 0]
# ['NYSE.EL', 4]
# ['NYSE.EMN', 4]
# ['NYSE.EMR', 4]
# ['NYSE.EOG', 3]
# ['NYSE.EQR', 0]
# ['NYSE.EQT', 2]
# ['NYSE.ES', 0]
# ['NYSE.ESS', 4]
# ['NYSE.ETN', 4]
# ['NYSE.ETR', 0]
# ['NYSE.EVHC', 2]
# ['NYSE.EW', 3]
# ['NYSE.EXC', 0]
# ['NYSE.EXR', 3]
# ['NYSE.F', 3]
# ['NYSE.FBHS', 4]
# ['NYSE.FCX', 1]
# ['NYSE.FDX', 0]
# ['NYSE.FE', 4]
# ['NYSE.FIS', 0]
# ['NYSE.FL', 1]
# ['NYSE.FLR', 2]
# ['NYSE.FLS', 2]
# ['NYSE.FMC', 3]
# ['NYSE.FRT', 3]
# ['NYSE.FTI', 2]
# ['NYSE.FTV', 4]
# ['NYSE.GD', 0]
# ['NYSE.GE', 4]
# ['NYSE.GGP', 2]
# ['NYSE.GIS', 0]
# ['NYSE.GLW', 4]
# ['NYSE.GM', 4]
# ['NYSE.GPC', 4]
# ['NYSE.GPN', 4]
# ['NYSE.GPS', 2]
# ['NYSE.GS', 3]
# ['NYSE.GWW', 2]
# ['NYSE.HAL', 3]
# ['NYSE.HBI', 3]
# ['NYSE.HCA', 3]
# ['NYSE.HCN', 4]
# ['NYSE.HCP', 4]
# ['NYSE.HD', 0]
# ['NYSE.HES', 2]
# ['NYSE.HIG', 0]
# ['NYSE.HOG', 2]
# ['NYSE.HON', 0]
# ['NYSE.HP', 2]
# ['NYSE.HPE', 3]
# ['NYSE.HPQ', 3]
# ['NYSE.HRB', 2]
# ['NYSE.HRL', 4]
# ['NYSE.HRS', 0]
# ['NYSE.HST', 3]
# ['NYSE.HSY', 0]
# ['NYSE.HUM', 4]
# ['NYSE.IBM', 0]
# ['NYSE.ICE', 4]
# ['NYSE.IFF', 4]
# ['NYSE.IP', 4]
# ['NYSE.IPG', 2]
# ['NYSE.IR', 4]
# ['NYSE.IRM', 4]
# ['NYSE.IT', 4]
# ['NYSE.ITW', 0]
# ['NYSE.IVZ', 3]
# ['NYSE.JCI', 3]
# ['NYSE.JEC', 3]
# ['NYSE.JNJ', 0]
# ['NYSE.JNPR', 3]
# ['NYSE.JPM', 4]
# ['NYSE.JWN', 1]
# ['NYSE.K', 0]
# ['NYSE.KEY', 2]
# ['NYSE.KIM', 2]
# ['NYSE.KMB', 0]
# ['NYSE.KMI', 3]
# ['NYSE.KMX', 2]
# ['NYSE.KO', 0]
# ['NYSE.KORS', 1]
# ['NYSE.KR', 1]
# ['NYSE.KSS', 2]
# ['NYSE.KSU', 3]
# ['NYSE.L', 0]
# ['NYSE.LB', 1]
# ['NYSE.LEG', 4]
# ['NYSE.LEN', 3]
# ['NYSE.LH', 4]
# ['NYSE.LLL', 4]
# ['NYSE.LLY', 4]
# ['NYSE.LMT', 0]
# ['NYSE.LNC', 3]
# ['NYSE.LNT', 0]
# ['NYSE.LOW', 4]
# ['NYSE.LUK', 4]
# ['NYSE.LUV', 3]
# ['NYSE.LVLT', 4]
# ['NYSE.LYB', 3]
# ['NYSE.M', 2]
# ['NYSE.MA', 0]
# ['NYSE.MAA', 4]
# ['NYSE.MAC', 3]
# ['NYSE.MAS', 4]
# ['NYSE.MCD', 0]
# ['NYSE.MCK', 3]
# ['NYSE.MCO', 4]
# ['NYSE.MDT', 0]
# ['NYSE.MET', 3]
# ['NYSE.MHK', 4]
# ['NYSE.MKC', 4]
# ['NYSE.MLM', 2]
# ['NYSE.MMC', 0]
# ['NYSE.MMM', 0]
# ['NYSE.MNK', 2]
# ['NYSE.MO', 4]
# ['NYSE.MON', 0]
# ['NYSE.MOS', 2]
# ['NYSE.MPC', 3]
# ['NYSE.MRK', 0]
# ['NYSE.MRO', 1]
# ['NYSE.MS', 3]
# ['NYSE.MSI', 4]
# ['NYSE.MTB', 3]
# ['NYSE.MUR', 2]
# ['NYSE.NBL', 2]
# ['NYSE.NEE', 0]
# ['NYSE.NEM', 3]
# ['NYSE.NFX', 1]
# ['NYSE.NI', 0]
# ['NYSE.NKE', 3]
# ['NYSE.NLSN', 4]
# ['NYSE.NOC', 0]
# ['NYSE.NOV', 2]
# ['NYSE.NRG', 1]
# ['NYSE.NSC', 4]
# ['NYSE.NUE', 2]
# ['NYSE.NWL', 3]
# ['NYSE.O', 4]
# ['NYSE.OKE', 3]
# ['NYSE.OMC', 4]
# ['NYSE.ORCL', 3]
# ['NYSE.OXY', 4]
# ['NYSE.PCG', 0]
# ['NYSE.PEG', 0]
# ['NYSE.PEP', 0]
# ['NYSE.PFE', 0]
# ['NYSE.PFG', 4]
# ['NYSE.PG', 0]
# ['NYSE.PGR', 0]
# ['NYSE.PH', 4]
# ['NYSE.PHM', 3]
# ['NYSE.PKI', 4]
# ['NYSE.PLD', 0]
# ['NYSE.PM', 4]
# ['NYSE.PNC', 3]
# ['NYSE.PNR', 4]
# ['NYSE.PNW', 0]
# ['NYSE.PPG', 4]
# ['NYSE.PPL', 0]
# ['NYSE.PRGO', 1]
# ['NYSE.PRU', 4]
# ['NYSE.PSA', 3]
# ['NYSE.PSX', 0]
# ['NYSE.PVH', 2]
# ['NYSE.PWR', 3]
# ['NYSE.PX', 4]
# ['NYSE.PXD', 2]
# ['NYSE.RAI', 0]
# ['NYSE.RCL', 3]
# ['NYSE.REG', 3]
# ['NYSE.RF', 2]
# ['NYSE.RHI', 3]
# ['NYSE.RHT', 3]
# ['NYSE.RIG', 1]
# ['NYSE.RJF', 3]
# ['NYSE.RL', 2]
# ['NYSE.ROK', 4]
# ['NYSE.ROP', 4]
# ['NYSE.RRC', 1]
# ['NYSE.RSG', 0]
# ['NYSE.RTN', 0]
# ['NYSE.SCG', 4]
# ['NYSE.SCHW', 3]
# ['NYSE.SEE', 4]
# ['NYSE.SHW', 4]
# ['NYSE.SIG', 1]
# ['NYSE.SJM', 4]
# ['NYSE.SLB', 4]
# ['NYSE.SLG', 4]
# ['NYSE.SNA', 3]
# ['NYSE.SO', 0]
# ['NYSE.SPG', 3]
# ['NYSE.SPGI', 4]
# ['NYSE.SRE', 0]
# ['NYSE.STI', 3]
# ['NYSE.STT', 4]
# ['NYSE.STZ', 3]
# ['NYSE.SWK', 4]
# ['NYSE.SYF', 1]
# ['NYSE.SYK', 0]
# ['NYSE.SYY', 4]
# ['NYSE.T', 0]
# ['NYSE.TAP', 4]
# ['NYSE.TDG', 2]
# ['NYSE.TEL', 4]
# ['NYSE.TGT', 2]
# ['NYSE.TIF', 3]
# ['NYSE.TJX', 4]
# ['NYSE.TMK', 0]
# ['NYSE.TMO', 4]
# ['NYSE.TRV', 0]
# ['NYSE.TSN', 3]
# ['NYSE.TSO', 4]
# ['NYSE.TSS', 4]
# ['NYSE.TWX', 0]
# ['NYSE.TXT', 4]
# ['NYSE.UA', 2]
# ['NYSE.UAA', 1]
# ['NYSE.UAL', 3]
# ['NYSE.UDR', 4]
# ['NYSE.UHS', 3]
# ['NYSE.UNH', 0]
# ['NYSE.UNM', 4]
# ['NYSE.UNP', 4]
# ['NYSE.UPS', 0]
# ['NYSE.URI', 2]
# ['NYSE.USB', 4]
# ['NYSE.UTX', 0]
# ['NYSE.V', 0]
# ['NYSE.VAR', 4]
# ['NYSE.VFC', 4]
# ['NYSE.VLO', 4]
# ['NYSE.VMC', 2]
# ['NYSE.VNO', 2]
# ['NYSE.VTR', 4]
# ['NYSE.VZ', 0]
# ['NYSE.WAT', 3]
# ['NYSE.WEC', 0]
# ['NYSE.WFC', 4]
# ['NYSE.WHR', 3]
# ['NYSE.WM', 0]
# ['NYSE.WMB', 3]
# ['NYSE.WMT', 4]
# ['NYSE.WRK', 3]
# ['NYSE.WU', 4]
# ['NYSE.WY', 4]
# ['NYSE.WYN', 4]
# ['NYSE.XEC', 2]
# ['NYSE.XEL', 0]
# ['NYSE.XL', 4]
# ['NYSE.XOM', 0]
# ['NYSE.XYL', 4]
# ['NYSE.YUM', 0]
# ['NYSE.ZBH', 3]
# ['NYSE.ZTS', 4]

# %%
df = pd.DataFrame(details, columns=['Stock_Name','Cluster_No'])
df.Cluster_No.value_counts()
# Out:
# 4    153
# 3    122
# 0    102
# 2     94
# 1     28
# Name: Cluster_No, dtype: int64

# %%
import seaborn as sns
ind = df.Cluster_No.value_counts()
plt.figure(figsize=(12,4))
sns.barplot(x=ind.index, y=ind.values, alpha=0.6)
plt.ylabel('Number of Occurences',fontsize=12)
plt.xlabel('Cluster Number',fontsize=12)
plt.title('Barplot - Indicator',fontsize =16)
plt.show()

# %% [markdown]
# #### Problem 3: Identify which all stocks are moving together and which all stocks are different from each other.

# %%
# Apply PCA to identify the stocks correlated with each other
data.head()
# Out:
#    NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  \
# 0     42.3300     143.6800     129.6300      82.040    102.2300      85.2200
# 1     42.3600     143.7000     130.3200      82.080    102.1400      85.6500
# 2     42.3100     143.6901     130.2250      82.030    102.2125      85.5100
# 3     42.3700     143.6400     130.0729      82.000    102.1400      85.4872
# 4     42.5378     143.6600     129.8800      82.035    102.0600      85.7001
#
#    NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  NASDAQ.AMD    ...     NYSE.WY  \
# 0       59.760       121.52        38.99       14.61    ...       34.00
# 1       59.840       121.48        39.01       14.71    ...       34.07
# 2       59.795       121.93        38.91       14.64    ...       34.11
# 3       59.620       121.44        38.84       14.63    ...       33.97
# 4       59.620       121.60        38.93       14.67    ...       34.00
#
#    NYSE.WYN  NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XYL  NYSE.YUM  \
# 0    84.370   119.035     44.40    39.88     82.03     50.22     63.86
# 1    84.370   119.035     44.11    39.88     82.03     50.22     63.74
# 2    84.585   119.260     44.09    39.98     82.02     50.12     63.75
# 3    84.460   119.260     44.25    39.99     82.02     50.16     63.88
# 4    84.470   119.610     44.11    39.96     82.03     50.20     63.91
#
#    NYSE.ZBH  NYSE.ZTS
# 0   122.000    53.350
# 1   121.770    53.350
# 2   121.700    53.365
# 3   121.700    53.380
# 4   121.695    53.240
#
# [5 rows x 499 columns]

# %%
data.head()
# Out:
#    NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  \
# 0     42.3300     143.6800     129.6300      82.040    102.2300      85.2200
# 1     42.3600     143.7000     130.3200      82.080    102.1400      85.6500
# 2     42.3100     143.6901     130.2250      82.030    102.2125      85.5100
# 3     42.3700     143.6400     130.0729      82.000    102.1400      85.4872
# 4     42.5378     143.6600     129.8800      82.035    102.0600      85.7001
#
#    NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  NASDAQ.AMD    ...     NYSE.WY  \
# 0       59.760       121.52        38.99       14.61    ...       34.00
# 1       59.840       121.48        39.01       14.71    ...       34.07
# 2       59.795       121.93        38.91       14.64    ...       34.11
# 3       59.620       121.44        38.84       14.63    ...       33.97
# 4       59.620       121.60        38.93       14.67    ...       34.00
#
#    NYSE.WYN  NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XYL  NYSE.YUM  \
# 0    84.370   119.035     44.40    39.88     82.03     50.22     63.86
# 1    84.370   119.035     44.11    39.88     82.03     50.22     63.74
# 2    84.585   119.260     44.09    39.98     82.02     50.12     63.75
# 3    84.460   119.260     44.25    39.99     82.02     50.16     63.88
# 4    84.470   119.610     44.11    39.96     82.03     50.20     63.91
#
#    NYSE.ZBH  NYSE.ZTS
# 0   122.000    53.350
# 1   121.770    53.350
# 2   121.700    53.365
# 3   121.700    53.380
# 4   121.695    53.240
#
# [5 rows x 499 columns]

# %%
dt = data.copy()

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# convert data into numpy arrays
X = dt.values

# Scaling the values
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

pca = PCA(n_components=150)
pca.fit(X_scaled)

# the amount of variance that each PCA explains
var = pca.explained_variance_ratio_

# cumulative varince explains
var1 = np.cumsum(np.round(var, decimals=4)*100)
print(var1)
# Out:
# [46.97 64.24 76.27 81.13 84.93 87.74 89.74 91.05 92.1  92.85 93.53 94.11
#  94.58 95.03 95.44 95.79 96.12 96.38 96.61 96.83 97.02 97.18 97.33 97.46
#  97.59 97.71 97.82 97.92 98.01 98.09 98.17 98.25 98.32 98.39 98.45 98.51
#  98.57 98.62 98.67 98.72 98.76 98.8  98.84 98.88 98.92 98.95 98.98 99.01
#  99.04 99.07 99.1  99.13 99.16 99.18 99.2  99.22 99.24 99.26 99.28 99.3
#  99.32 99.34 99.36 99.38 99.4  99.42 99.44 99.46 99.47 99.48 99.49 99.5
#  99.51 99.52 99.53 99.54 99.55 99.56 99.57 99.58 99.59 99.6  99.61 99.62
#  99.63 99.64 99.65 99.66 99.67 99.68 99.69 99.7  99.71 99.72 99.73 99.74
#  99.75 99.76 99.77 99.78 99.79 99.8  99.8  99.8  99.8  99.8  99.8  99.8
#  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8
#  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8
#  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8  99.8
#  99.8  99.8  99.8  99.8  99.8  99.8 ]

# %%
plt.plot(var1)

# %%
# Looking at above plot we can consider 25 variables 
pca = PCA(n_components =25)
X1 = pca.fit_transform(X_scaled)
print(X1)
# Out:
# [[ 25.54489969   9.98399845  -9.36306484 ...   0.55552996   0.10784465
#     2.4127472 ]
#  [ 25.64396757   9.87058075  -9.78352591 ...   0.45747598   0.19435828
#     2.30303568]
#  [ 25.55832141   9.80326405  -9.65680691 ...   0.53384964   0.06011159
#     2.04786048]
#  ...
#  [-22.74268953  13.34385803   6.52612773 ...  -2.13828497   1.21970855
#    -0.33102689]
#  [-22.58678189  13.43459792   6.63993624 ...  -2.12397419   1.22539996
#    -0.35759987]
#  [-22.69505715  13.37926134   6.56805244 ...  -2.16139762   1.20613453
#    -0.31719665]]

# %%
print('Number of PCA :',len(pca.components_))
print(abs(pca.components_))
# Out:
# Number of PCA : 25
# [[0.03932727 0.04119779 0.06302875 ... 0.06260427 0.00257534 0.05182548]
#  [0.06427995 0.03397585 0.00193476 ... 0.02032991 0.08130274 0.05943219]
#  [0.03996486 0.06394349 0.01187376 ... 0.02086513 0.06626943 0.02349888]
#  ...
#  [0.011094   0.00463245 0.0047782  ... 0.01182123 0.04407199 0.01141772]
#  [0.0745339  0.01902863 0.01018831 ... 0.00152115 0.01855954 0.0484864 ]
#  [0.02229127 0.03318693 0.03687779 ... 0.00427167 0.02076759 0.02477304]]

# %%
comp = pd.DataFrame(pca.components_, columns = dt.columns)
comp.head()
# Out:
#    NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  \
# 0   -0.039327    -0.041198    -0.063029   -0.009854   -0.035888    -0.054813
# 1   -0.064280     0.033976     0.001935   -0.032403    0.043516    -0.029425
# 2   -0.039965     0.063943     0.011874    0.043297   -0.037457     0.040367
# 3    0.007225     0.077156     0.008401   -0.028080   -0.018027     0.008762
# 4   -0.033182    -0.017369     0.002557   -0.038106   -0.101883    -0.034799
#
#    NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  NASDAQ.AMD    ...      NYSE.WY  \
# 0     0.050489    -0.035384    -0.044205   -0.014613    ...     0.044324
# 1     0.016081     0.058270    -0.052583    0.012303    ...    -0.022112
# 2    -0.053789    -0.051299     0.030592   -0.086503    ...    -0.046046
# 3    -0.032382     0.034501     0.051270   -0.078063    ...    -0.054202
# 4    -0.010965     0.037455    -0.039823   -0.013665    ...    -0.081522
#
#    NYSE.WYN  NYSE.XEC  NYSE.XEL   NYSE.XL  NYSE.XOM  NYSE.XYL  NYSE.YUM  \
# 0 -0.049520  0.057072 -0.054750 -0.050685  0.047282 -0.061482 -0.062604
# 1 -0.058897  0.030257  0.013746 -0.040753 -0.052867  0.031522 -0.020330
# 2 -0.003326  0.022205  0.059502 -0.034738 -0.028530 -0.004580  0.020865
# 3  0.021500  0.061063 -0.039785  0.027499  0.012080  0.002698 -0.002802
# 4 -0.036786 -0.011903 -0.030101 -0.012076 -0.045974 -0.002891 -0.001254
#
#    NYSE.ZBH  NYSE.ZTS
# 0  0.002575 -0.051825
# 1 -0.081303 -0.059432
# 2 -0.066269  0.023499
# 3 -0.049638  0.015167
# 4 -0.003203  0.005309
#
# [5 rows x 499 columns]
